# %% [markdown]
# ### Confusion Matrix 기본 원리

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
y_actual = [1, 1, 0, 1, 0, 0, 1, 0, 0, 0]
y_pred = [1, 0, 0, 1, 0, 0, 1, 1, 1, 0]

CM = confusion_matrix(y_actual, y_pred)
print('Confusion Matrix = \n', CM)
# Out:
# Confusion Matrix =
#  [[4 2]
#  [1 3]]

# %% [markdown]
# ### Confusion Matrix 시각화 함수

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion Matrix',
                          camp=plt.cm.Blues):

    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print('Normalized Confusion Matrix')
    else:
        print('Confusion Matrix, without normalization')
        print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arrange(len(classes))
    plt.xticks(tick_marks, classes, rotaion-45)
    plt.yticks(tick_marks, classes)

    fmt='.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment='center',
                 color='white' if cm[i, j] > thresh else 'black')
    plt.ylabel()
    plt.xlabel()
    plt.tight_layout()

# %%
cnf_matrix = confusion_matrix(y_actual, y_pred, labels=[0,1])

plt.figure
plot_confusion_matrix(cnf_matrix, classes=[0,1],
                      title = 'Confusion Matrix')
# Out:
# Confusion Matrix, without normalization
# [[4 2]
#  [1 3]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-34-1199127480.py in <cell line: 0>()
#       2
#       3 plt.figure
# ----> 4 plot_confusion_matrix(cnf_matrix, classes=[0,1],
#       5                       title = 'Confusion Matrix')
#
# /tmp/ipython-input-33-1379498274.py in plot_confusion_matrix(cm, classes, normalize, title, camp)
#      15     plt.title(title)
#      16     plt.colorbar()
# ---> 17     tick_marks = np.arrange(len(classes))
#      18     plt.xticks(tick_marks, classes, rotaion-45)
#      19     plt.yticks(tick_marks, classes)
#
# /usr/local/lib/python3.11/dist-packages/numpy/__init__.py in __getattr__(attr)
#     408             return char.chararray
#     409
# --> 410         raise AttributeError("module {!r} has no attribute "
#     411                              "{!r}".format(__name__, attr))
#     412
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
import seaborn as sns

cnf_matrix = confusion_matrix(y_actual, y_pred, labels=[0,1])

plt.figure(figsize=(6, 4))
sns.heatmap(cnf_matrix, annot=True, cmap='Blues', xticklabels=['seatbelt','none'])
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print('Accuracy =', accuracy_score(y_actual, y_pred))
print('Report = \n', classification_report(y_actual, y_pred))
# Out:
# Accuracy = 0.7
# Report =
#                precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.60      0.75      0.67         4
#
#     accuracy                           0.70        10
#    macro avg       0.70      0.71      0.70        10
# weighted avg       0.72      0.70      0.70        10
