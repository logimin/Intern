# %% [markdown]
# # ONNX
# ### Open Neural Network Exchange
# ### DNN 프레임워크 환경에서 만들어진 모델들을 호환할 수 있도록 해주는 플랫폼

# %%
! pip install onnx
! pip install onnx_tf
! pip install keras

# %%
# PyTorch에서 모델 내보내기

import torch
import torch.nn as nn
import torch.onnx

# Define your PyTorch model
class MyModel(torch.nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.linear = torch.nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

model = MyModel()

# Export the PyTorch model to ONNX format
input_shape = (1, 1)
x = torch.randn(input_shape)
torch.onnx.export(model, x, "model.onnx", input_names=["input"], output_names=["output"])

# %%
# ONNX로 모델 가져오기

import onnx
import tensorflow as tf
from onnx_tf.backend import prepare

# Load the ONNX model
onnx_model = onnx.load("/content/efficientnet_lite0_best.onnx")

# Convert the ONNX model to TensorFlow format
tf_model = prepare(onnx_model)

# Use the TensorFlow model
output = tf_model.run({"input": x.numpy()})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-11-1690997886.py in <cell line: 0>()
#       2
#       3 import onnx
# ----> 4 import keras.src.engine
#       5 import tensorflow as tf
#       6 from onnx_tf.backend import prepare
#
# ModuleNotFoundError: No module named 'keras.src.engine'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### netron에서 onnx 파일을 열어볼 수도 있다.
